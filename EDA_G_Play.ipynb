# %%
#CRISPDM--CROSS INDUSTRY STANDARD FOR DATA MINING

# %%
"""
1. data ingestion(.csv,.tsv,.xlsx)
2. exploratory data analysis
3. data preperation/feature engineering
4. model building
5. model evaluation
"""
# Out:
# '\n1. data ingestion(.csv,.tsv,.xlsx)\n2. exploratory data analysis\n3. data preperation/feature engineering\n4. model building\n5. model evaluation\n'

# %%
"""
-profile of data-number of rows,column data type,duplicate
-statistical based analysis-five point summary,outliers,correlation,covariance
-graphical based analysis-scatter plot,heat map, pair plot,boxplot,piplot
"""

"""
once you understand the data-select relevant features,convert the data to numerical columns
"""
# Out:
# '\nonce you understand the data-select relevant features,convert the data to numerical columns\n'

# %%
""" EDA_Types
-univariats analysis-1 feature,distplot
-bivariate analysis-2 features at a time,scatter_plot
-multi-variate analysis-more than 2 features at a time,heatmap,pairplot and so on.
"""
# Out:
# ' EDA_Types\n-univariats analysis-1 feature,distplot\n-bivariate analysis-2 features at a time,scatter_plot\n-multi-variate analysis-more than 2 features at a time,heatmap,pairplot and so on.\n'

# %%
#Data Preperation-EDA
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#step_1_read_the_file
df=pd.read_csv("googleplaystore.csv")

# %%
#used to read columns
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail(5)
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
#any_2_random_data
df.sample(2)
# Out:
#               App       Category  Rating Reviews                Size  \
# 9321  EG CrossPad       BUSINESS     NaN       3  Varies with device
# 870          H TV  ENTERTAINMENT     4.3  103078                5.6M
#
#         Installs  Type Price Content Rating         Genres       Last Updated  \
# 9321      1,000+  Free     0       Everyone       Business  December 19, 2016
# 870   5,000,000+  Free     0       Everyone  Entertainment       July 5, 2018
#
#              Current Ver         Android Ver
# 9321  Varies with device  Varies with device
# 870                4.6.2        2.3.3 and up

# %%
df.shape
# Out:
# (10841, 13)

# %%
#give statistical information_5_point_summary_give_only_of_numerical_data
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include="all")  #for categorical columns
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
#data types of each column
df.dtypes  # all columns data type together
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#to check duplicate values
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
df=df.drop_duplicates()   #it will drop duplicates value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#for one column data_type
df['Content Rating'].dtype
# Out:
# dtype('O')

# %%
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
#to check unique values of any column
df['Reviews'].unique()
# it is possible that their might be a value which is string and hence
# converting whole column into object/categorical
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'],
#       shape=(6002,), dtype=object)

# %%
#to check where our value is having a string value - we use ~ symbol
df[~df.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_copy=df.copy()

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#reseting the index-after dropiing the duplicates values original index is still there
df_copy.reset_index(drop=True,inplace=True)

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy[~df_copy.Reviews.str.isnumeric()]
# Out:
#                                           App Category  Rating Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
#drop for a specific index
df_copy=df_copy.drop(df_copy.index[9990])

# %%
df_copy[~df_copy.Reviews.str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df_copy.Reviews
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10353        38
# 10354         4
# 10355         3
# 10356       114
# 10357    398307
# Name: Reviews, Length: 10357, dtype: object

# %%
#to_convert_dtype_of_a_sepcific_column
df_copy['Reviews']=df_copy['Reviews'].astype(int)

# %%
df_copy['Reviews'].astype
# Out:
# <bound method NDFrame.astype of 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10353        38
# 10354         4
# 10355         3
# 10356       114
# 10357    398307
# Name: Reviews, Length: 10357, dtype: int64>

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            10357 non-null  object
#  5   Installs        10357 non-null  object
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df_copy['Size'].astype
# Out:
# <bound method NDFrame.astype of 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10353                   53M
# 10354                  3.6M
# 10355                  9.5M
# 10356    Varies with device
# 10357                   19M
# Name: Size, Length: 10357, dtype: object>

# %%
df_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
def size_process(item):
    if str(item)[-1]=="M":
        res=float(str(item).replace("M",""))
        res=res*1024
        return res
    elif str(item)[-1]=="K":
        res=float(str(item).replace("K",""))
        return res
    else:
        return str(np.nan)

# %%
size_process("19M")
# Out:
# 19456.0

# %%
df_copy["Size"]=df_copy['Size'].apply(size_process)

# %%
df_copy['Size'].unique()
# Out:
# array([19456.0, 14336.0, 8908.8, 25600.0, 2867.2, 5734.4, 29696.0,
#        33792.0, 3174.4, 28672.0, 12288.0, 20480.0, 21504.0, 37888.0,
#        2764.8, 5632.0, 17408.0, 39936.0, 31744.0, 4300.8, 7168.0, 23552.0,
#        6144.0, 6246.4, 4710.4, 9420.8, 5324.8, 11264.0, 24576.0, 'nan',
#        9625.6, 15360.0, 10240.0, 1228.8, 26624.0, 8192.0, 8089.6, 57344.0,
#        58368.0, 35840.0, 55296.0, 3686.4, 5836.8, 8806.4, 2457.6, 27648.0,
#        2560.0, 16384.0, 3481.6, 9113.6, 3993.6, 2969.6, 38912.0, 32768.0,
#        5529.6, 18432.0, 1126.4, 2252.8, 4608.0, 10035.2, 53248.0, 9216.0,
#        6860.8, 30720.0, 2662.4, 7270.4, 3788.8, 22528.0, 7577.6, 6553.6,
#        3276.8, 8396.8, 10137.6, 5017.6, 9728.0, 5120.0, 6041.6, 13312.0,
#        74752.0, 6963.2, 3584.0, 4096.0, 2355.2, 7372.8, 2150.4, 43008.0,
#        7475.2, 9318.4, 56320.0, 6656.0, 1536.0, 7680.0, 52224.0, 41984.0,
#        49152.0, 8704.0, 47104.0, 8499.2, 4403.2, 4812.8, 3379.2, 40960.0,
# ...

# %%
df_copy['Size'].dtype
# Out:
# dtype('O')

# %%
df_copy["Size"]=df_copy['Size'].astype(float)

# %%
df_copy["Size"].dtype
# Out:
# dtype('float64')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8516 non-null   float64
#  5   Installs        10357 non-null  object
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
df_copy['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df_copy['Installs']=df_copy['Installs'].str.replace("+","").str.replace(",","")

# %%
df_copy['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df_copy['Installs']=df_copy['Installs'].astype(int)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8516 non-null   float64
#  5   Installs        10357 non-null  int64
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %%
df_copy["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
char_to_remove=["+",",","$"]
cols_to_remove=["Price"]
for char in char_to_remove:
    for col in cols_to_remove:
        df_copy[col]=df_copy[col].str.replace(char,"")

# %%
df_copy.Price.unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df_copy['Price']=df_copy['Price'].astype(float)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8516 non-null   float64
#  5   Installs        10357 non-null  int64
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
df_copy['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       shape=(1377,), dtype=object)

# %%
df_copy['Last Updated']=pd.to_datetime(df_copy['Last Updated'])

# %%
df_copy['Last Updated'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_copy['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10353   2017-07-25
# 10354   2018-07-06
# 10355   2017-01-20
# 10356   2015-01-19
# 10357   2018-07-25
# Name: Last Updated, Length: 10357, dtype: datetime64[ns]

# %%
df_copy['day']=df_copy['Last Updated'].dt.day

# %%
df_copy['month']=df_copy['Last Updated'].dt.month

# %%
df_copy["year"]=df_copy['Last Updated'].dt.year

# %%
df_copy.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                    int64
# Size                     float64
# Installs                   int64
# Type                      object
# Price                    float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# day                        int32
# month                      int32
# year                       int32
# dtype: object

# %%
df_copy.drop("Last Updated",axis=1,inplace=True)

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df_copy['Android Ver']=df_copy['Android Ver'].str.replace(" and up","").str.replace("Varies with device","")

# %%
df_copy['Android Ver'].unique()
# Out:
# array(['4.0.3', '4.2', '4.4', '2.3', '3.0', '4.1', '4.0', '2.3.3', '',
#        '2.2', '5.0', '6.0', '1.6', '1.5', '2.1', '7.0', '5.1', '4.3',
#        '4.0.3 - 7.1.1', '2.0', '3.2', '4.4W', '7.1', '7.0 - 7.1.1', '8.0',
#        '5.0 - 8.0', '3.1', '2.0.1', '4.1 - 7.1.1', nan, '5.0 - 6.0',
#        '1.0', '2.2 - 7.1.1', '5.0 - 7.1.1'], dtype=object)

# %%
df_copy['Android Ver']=df_copy['Android Ver'].str.replace("W","").str.replace("nan","")

# %%
df_copy['Android Ver']=df_copy['Android Ver'].str.replace("4.0.3 - 7.1.1","4.0").str.replace("7.0 - 7.1.1","").str.replace("5.0 - 8.0","5.0").str.replace("2.0.1","2.0").str.replace("2.2 - 7.1.1","2.2").str.replace("5.0 - 7.1.1","5.0").str.replace("5.0 - 6.0","5.0").str.replace("5.0 - 7.1.1","5.0")

# %%
df_copy['Android Ver'].unique()
# Out:
# array(['4.0.3', '4.2', '4.4', '2.3', '3.0', '4.1', '4.0', '2.3.3', '',
#        '2.2', '5.0', '6.0', '1.6', '1.5', '2.1', '7.0', '5.1', '4.3',
#        '2.0', '3.2', '7.1', '8.0', '3.1', '4.1 - 7.1.1', nan, '1.0'],
#       dtype=object)

# %%
df_copy['Android Ver']=df_copy['Android Ver'].str.replace("nan","0").str.replace("4.1 - 7.1.1","4.1").str.replace("4.0.3","4.0")

# %%
df_copy['Android Ver'].unique()
# Out:
# array(['4.0', '4.2', '4.4', '2.3', '3.0', '4.1', '2.3.3', '', '2.2',
#        '5.0', '6.0', '1.6', '1.5', '2.1', '7.0', '5.1', '4.3', '2.0',
#        '3.2', '7.1', '8.0', '3.1', nan, '1.0'], dtype=object)

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
df_copy['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10353                                     Sya9a Maroc - FR
# 10354                     Fr. Mike Schmitz Audio Teachings
# 10355                               Parkinson Exercices FR
# 10356                        The SCP Foundation DB fr nn5n
# 10357        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10357, dtype: object

# %%
df_copy[df_copy.duplicated('App')]
# Out:
#                                             App       Category  Rating  \
# 260                Quick PDF Scanner + OCR FREE       BUSINESS     4.2
# 261      OfficeSuite : Free Office + PDF Editor       BUSINESS     4.3
# 262                                       Slack       BUSINESS     4.4
# 348    Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 349               imo free video calls and chat  COMMUNICATION     4.3
# ...                                         ...            ...     ...
# 10165                         Motorola FM Radio  VIDEO_PLAYERS     3.9
# 10233                        FarmersOnly Dating         DATING     3.0
# 10238        Firefox Focus: The privacy browser  COMMUNICATION     4.4
# 10248                               FP Notebook        MEDICAL     4.5
# 10271            Slickdeals: Coupons & Shopping       SHOPPING     4.5
#
#         Reviews     Size    Installs  Type  Price Content Rating  \
# ...

# %%
df_copy=df_copy.drop_duplicates(subset=['App'],keep='first')

# %%
df_copy[df_copy.duplicated('App')]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Current Ver, Android Ver, day, month, year]
# Index: []

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
#Exploratory Data Analysis
categorical_features=[feature for feature in df_copy.columns if df_copy[feature].dtype=="O"]

# %%
numerical_col=[feature for feature in df_copy.columns if df_copy[feature].dtype!="O"]
numerical_col
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
df_copy[categorical_features]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#categorical data >> freq plot,bar chart , pie char
#numerical data >> histplot,distplot,box plot,line chart,pairplot ,scatter plot

# %%
#categorical feature analysis
df_copy['Type'].value_counts(normalize=True)*100
# Out:
# Type
# Free    92.172292
# Paid     7.827708
# Name: proportion, dtype: float64

# %%
for col in categorical_features:
    print(f"{col}:{df_copy[col].value_counts(normalize=True)*100}")
# Out:
# App:App
# Photo Editor & Candy Camera & Grid & ScrapBook        0.010353
# Coloring book moana                                   0.010353
# U Launcher Lite – FREE Live Cool Themes, Hide Apps    0.010353
# Sketch - Draw & Paint                                 0.010353
# Pixel Draw - Number Art Coloring Book                 0.010353
#                                                         ...
# Sya9a Maroc - FR                                      0.010353
# Fr. Mike Schmitz Audio Teachings                      0.010353
# Parkinson Exercices FR                                0.010353
# The SCP Foundation DB fr nn5n                         0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology         0.010353
# Name: proportion, Length: 9659, dtype: float64
# Category:Category
# FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# ...

# %%
df_copy['Android Ver'].value_counts(normalize=True)*100
# Out:
# Android Ver
# 4.0      27.772600
# 4.1      22.812468
#          10.261986
# 4.4       8.584447
# 2.3       6.378793
# 5.0       5.343274
# 4.2       3.852128
# 2.3.3     2.826965
# 2.2       2.485244
# 3.0       2.392047
# 4.3       2.288495
# 2.1       1.377239
# 1.6       1.201201
# 6.0       0.559180
# 7.0       0.434918
# 2.0       0.403852
# 3.2       0.372787
# 5.1       0.227814
# 1.5       0.207104
# 3.1       0.103552
# 8.0       0.062131
# 7.1       0.031066
# 1.0       0.020710
# Name: proportion, dtype: float64

# %%
df_copy['Type'].value_counts(normalize=True)*100
# Out:
# Type
# Free    92.172292
# Paid     7.827708
# Name: proportion, dtype: float64

# %%
sns.countplot(df_copy['Type'])
# Out:
# <Axes: xlabel='count', ylabel='Type'>

# %%
#sns.countplot(df_copy.C
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
numerical_col
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
sns.distplot(df_copy['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df_copy['Rating'],kde=True)
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.kdeplot(df_copy['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
#two plot in one plot
plt.figure(figsize=(20,15))
category=['Type',"Content Rating"]
for i in range(0,len(category)):
    
    plt.subplot(2,2,i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
#most popular category in the app
df_copy["Category"].value_counts().plot.pie(y=df['Category'],figsize=(12,12),autopct='%1.1f')
# Out:
# <Axes: ylabel='count'>

# %%
#insight>>  the nost popular category with the 19 percent of share is family category.

# %%
#top 10 most popular category
cat=df_copy['Category'].value_counts()[:10]

# %%
category=cat.reset_index()

# %%
category
# Out:
#           Category  count
# 0           FAMILY   1832
# 1             GAME    959
# 2            TOOLS    827
# 3         BUSINESS    420
# 4          MEDICAL    395
# 5  PERSONALIZATION    376
# 6     PRODUCTIVITY    374
# 7        LIFESTYLE    369
# 8          FINANCE    345
# 9           SPORTS    325

# %%
category.columns=['Groups',"count"]

# %%
category
# Out:
#             Groups  count
# 0           FAMILY   1832
# 1             GAME    959
# 2            TOOLS    827
# 3         BUSINESS    420
# 4          MEDICAL    395
# 5  PERSONALIZATION    376
# 6     PRODUCTIVITY    374
# 7        LIFESTYLE    369
# 8          FINANCE    345
# 9           SPORTS    325

# %%
sns.barplot(category,x=category['Groups'],y=category['count'],palette='Set2')
# Out:
# <Axes: xlabel='Groups', ylabel='count'>

# %%
#category has the highest installation
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
df_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()
# Out:
#                Category     Installs
# 0                  GAME  13878924415
# 1         COMMUNICATION  11038276251
# 2                 TOOLS   8001771915
# 3          PRODUCTIVITY   5793091369
# 4                SOCIAL   5487867902
# 5           PHOTOGRAPHY   4649147655
# 6                FAMILY   4427941505
# 7         VIDEO_PLAYERS   3926902720
# 8      TRAVEL_AND_LOCAL   2894887146
# 9    NEWS_AND_MAGAZINES   2369217760
# 10        ENTERTAINMENT   2113660000
# 11  BOOKS_AND_REFERENCE   1665969576
# 12      PERSONALIZATION   1532494782
# 13             SHOPPING   1400348785
# 14   HEALTH_AND_FITNESS   1144022512
# 15               SPORTS   1096474498
# 16             BUSINESS    697164865
# 17            LIFESTYLE    503823539
# 18  MAPS_AND_NAVIGATION    503281890
# 19              FINANCE    455348734
# 20              WEATHER    361100520
# 21            EDUCATION    352952000
# 22       FOOD_AND_DRINK    211798751
# 23               DATING    140926107
# ...

# %%
sns.boxplot(df_copy['Rating'])
# Out:
# <Axes: ylabel='Rating'>

# %%
sns.boxplot(x='Installs',y='Rating',data=df_copy,palette="Set2")
# Out:
# <Axes: xlabel='Installs', ylabel='Rating'>

# %%
#what are top 5 installed category apps in each type?
#group by category and type column with aggregation on installs columns

# %%
df_copy.groupby(['Category','Type'])['Installs'].sum().sort_values(ascending=False).reset_index()
# Out:
#               Category  Type     Installs
# 0                 GAME  Free  13857924450
# 1        COMMUNICATION  Free  11036916201
# 2                TOOLS  Free   8000044474
# 3         PRODUCTIVITY  Free   5791679314
# 4               SOCIAL  Free   5487861902
# ..                 ...   ...          ...
# 58            SHOPPING  Paid        10100
# 59              SOCIAL  Paid         6000
# 60  NEWS_AND_MAGAZINES  Paid         5500
# 61  LIBRARIES_AND_DEMO  Paid          100
# 62              EVENTS  Paid            1
#
# [63 rows x 3 columns]

# %%
#which category app users are reviewing the most? social facebook
#groupby category and app,aggregated sum on reviews
df_copy.groupby(['Category',"App"])['Reviews'].sum().sort_values(ascending=False).reset_index()
# Out:
#                 Category                                       App   Reviews
# 0                 SOCIAL                                  Facebook  78158306
# 1          COMMUNICATION                        WhatsApp Messenger  69119316
# 2                 SOCIAL                                 Instagram  66577313
# 3          COMMUNICATION  Messenger – Text and Video Chat for Free  56642847
# 4                   GAME                            Clash of Clans  44891723
# ...                  ...                                       ...       ...
# 9654            BUSINESS                      Bk Bee Sales Manager         0
# 9655            BUSINESS                        Border Ag & Energy         0
# 9656           LIFESTYLE                      Freedom Christian BF         0
# 9657  HEALTH_AND_FITNESS                             D.W Bien Être         0
# 9658            BUSINESS                            BV Productions         0
#
# [9659 rows x 3 columns]
