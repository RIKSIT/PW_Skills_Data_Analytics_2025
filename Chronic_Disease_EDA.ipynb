# %%
import numpy as no
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("kidney_disease.csv")

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.shape
# Out:
# (400, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
df.drop("id",axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  381.000000  383.000000  313.000000  312.000000  348.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437
# std     50.503006    5.741126   10.408752    3.193904    2.912587
# ...

# %%
df.dtypes
# Out:
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
df['pcv'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
#df['pcv'].replace("'\t4","43")

# %%
df['pcv']=pd.to_numeric(df['pcv'],errors='coerce')  #coerce-ignore

# %%
df.dtypes
# Out:
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv               float64
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
df['pcv'].unique()
# Out:
# array([44., 38., 31., 32., 35., 39., 36., 33., 29., 28., nan, 16., 24.,
#        37., 30., 34., 40., 45., 27., 48., 52., 14., 22., 18., 42., 17.,
#        46., 23., 19., 25., 41., 26., 15., 21., 43., 20., 47.,  9., 49.,
#        50., 53., 51., 54.])

# %%
df['wc'].unique()
# Out:
# array(['7800', '6000', '7500', '6700', '7300', nan, '6900', '9600',
#        '12100', '4500', '12200', '11000', '3800', '11400', '5300', '9200',
#        '6200', '8300', '8400', '10300', '9800', '9100', '7900', '6400',
#        '8600', '18900', '21600', '4300', '8500', '11300', '7200', '7700',
#        '14600', '6300', '\t6200', '7100', '11800', '9400', '5500', '5800',
#        '13200', '12500', '5600', '7000', '11900', '10400', '10700',
#        '12700', '6800', '6500', '13600', '10200', '9000', '14900', '8200',
#        '15200', '5000', '16300', '12400', '\t8400', '10500', '4200',
#        '4700', '10900', '8100', '9500', '2200', '12800', '11200', '19100',
#        '\t?', '12300', '16700', '2600', '26400', '8800', '7400', '4900',
#        '8000', '12000', '15700', '4100', '5700', '11500', '5400', '10800',
#        '9900', '5200', '5900', '9300', '9700', '5100', '6600'],
#       dtype=object)

# %%
df['wc']=pd.to_numeric(df['wc'],errors="coerce")
df['wc'].dtypes
# Out:
# dtype('float64')

# %%
df['rc']=pd.to_numeric(df['rc'],errors="coerce")
df['rc'].dtypes
# Out:
# dtype('float64')

# %%
cat_col=[col for col in df.columns if df[col].dtype=="object"]
cat_col
# Out:
# ['rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %%
num_col=[col for col in df.columns if df[col].dtype!="object"]
num_col
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'rc']

# %%
for col in cat_col:
    print(f"{col} has {df[col].unique()} values\n")
# Out:
# rbc has [nan 'normal' 'abnormal'] values
#
# pc has ['normal' 'abnormal' nan] values
#
# pcc has ['notpresent' 'present' nan] values
#
# ba has ['notpresent' 'present' nan] values
#
# htn has ['yes' 'no' nan] values
#
# dm has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# cad has ['no' 'yes' '\tno' nan] values
#
# appet has ['good' 'poor' nan] values
#
# pe has ['no' 'yes' nan] values
#
# ane has ['no' 'yes' nan] values
#
# classification has ['ckd' 'ckd\t' 'notckd'] values

# %%
df['dm'].replace(to_replace={"yes":"yes","\tyes":"yes","\tno":"no"},inplace=True)

# %%
df['dm'].unique()
# Out:
# array(['yes', 'no', ' yes', nan], dtype=object)

# %%
df['cad'].replace(to_replace={"\tno":"no"},inplace=True)

# %%
df['cad'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df['classification'].unique()
# Out:
# array(['ckd', 'ckd\t', 'notckd'], dtype=object)

# %%
df['classification']=df['classification'].map({"ckd":1,"notckd":0,"ckd\t":1})

# %%
df['classification']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 395    0
# 396    0
# 397    0
# 398    0
# 399    0
# Name: classification, Length: 400, dtype: int64

# %%
for col in cat_col:
    print(df[col].unique())
# Out:
# [nan 'normal' 'abnormal']
# ['normal' 'abnormal' nan]
# ['notpresent' 'present' nan]
# ['notpresent' 'present' nan]
# ['yes' 'no' nan]
# ['yes' 'no' ' yes' nan]
# ['no' 'yes' nan]
# ['good' 'poor' nan]
# ['no' 'yes' nan]
# ['no' 'yes' nan]
# [1 0]

# %%
#univariate analysis
#age
plt.figure(figsize=(10,6))
sns.histplot(df['age'].dropna(),kde=True,bins=20,color="skyblue")
plt.title("Dist_of_age")
plt.xlabel("age")
plt.ylabel("frequency")
plt.show()

# %%
#insights-age is left skewed data

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
#count the values of hypertension using countplot
sns.countplot(df['htn'],palette="Set2")

#insights-150 of them have hyper-tension
# Out:
# <Axes: xlabel='count', ylabel='htn'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.boxplot(x="classification",y="bu",data=df,palette="Set2")
#insights-people with kidney disease has higher blood urea with outliers , median value is also higher
# Out:
# <Axes: xlabel='classification', ylabel='bu'>

# %%
sns.violinplot(x=df['classification'],y=df['sc'],palette="muted")
# Out:
# <Axes: xlabel='classification', ylabel='sc'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
#using countplot checking how many peoples are suffering from anemia 
sns.countplot(x='ane',data=df,palette="pastel")

#majority of people nit suffering from anemia
# Out:
# <Axes: xlabel='ane', ylabel='count'>

# %%
df['appet'].value_counts()
# Out:
# appet
# good    317
# poor     82
# Name: count, dtype: int64

# %%
df['appet'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#pie-chart of appet
df['appet'].value_counts().plot.pie(autopct='%1.1f%%',colors=["lightcoral","lightgreen"],startangle=90,explode=(0,0.1),shadow=True)
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df['pc']
# Out:
# 0        normal
# 1        normal
# 2        normal
# 3      abnormal
# 4        normal
#          ...
# 395      normal
# 396      normal
# 397      normal
# 398      normal
# 399      normal
# Name: pc, Length: 400, dtype: object

# %%
sns.countplot(df['pc'],palette="Set2")
# Out:
# <Axes: xlabel='count', ylabel='pc'>

# %%
sns.histplot(df['wc'].dropna(),kde=True,bins=20,color="coral")
# Out:
# <Axes: xlabel='wc', ylabel='Count'>

# %%
#donut_chart/ring chart-pie chart with a hole in the center .
df['dm'].value_counts().plot.pie(autopct="%1.1f%%",wedgeprops=dict(width=0.3))
# Out:
# <Axes: ylabel='count'>

# %%
#df.columns
sns.countplot(x="cad",data=df,palette="Set2")
plt.grid()
#majority of people does not have cornanory arteiry disease

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
sns.countplot(df['pe'],palette="Set2")
# Out:
# <Axes: xlabel='count', ylabel='pe'>

# %%
#countplot of bacteria present or not 
sns.countplot(df['ba'],palette="Set2")
# Out:
# <Axes: xlabel='count', ylabel='ba'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
#using scatter plot analyze how bp varies as per age
sns.scatterplot(x=df['age'],y=df['bp'])  
#as age is increasing BP is also increasing
# Out:
# <Axes: xlabel='age', ylabel='bp'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['age'],y=df['bp'],hue=df['classification'],palette="Set2")
plt.grid()
plt.show()

# %%
sns.boxplot(x="dm",y='al',data=df)
# Out:
# <Axes: xlabel='dm', ylabel='al'>

# %%
sns.violinplot(x="dm",y='al',data=df,inner="quartile")
# Out:
# <Axes: xlabel='dm', ylabel='al'>

# %%
#barchart-dm,htn
pd.crosstab(df['dm'],df['htn'])
# Out:
# htn    no  yes
# dm
#  yes    0    1
# no    220   41
# yes    31  105

# %%
d_htn=pd.crosstab(df['dm'],df['htn'])

# %%
d_htn.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='dm'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
cols=['age','bp','bgr','sc','classification']
g=sns.PairGrid(df[cols],hue="classification",palette="coolwarm")
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot,cmap="Blues_d")
g.map_diag(sns.histplot)
g.add_legend()
plt.title("pairgrid for selected columns")
plt.show()

# %%
sns.pairplot(df[cols],hue="classification",palette="husl")

# %%
corr=df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
sns.swarmplot(x="dm",y="age",hue="htn",data=df,palette="Set2")
# Out:
# <Axes: xlabel='dm', ylabel='age'>

# %%
fig=px.scatter(df,x="age",y="bp",color="classification",hover_data=['sc',"hemo"])
fig.show()

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
fig1=px.scatter_3d(df,x="age",y="bp",z="sc",color="classification",title="3d scatter plot")
fig1.show()

# %%
#replace with median,mean >> for numeric cols 
median_values=df[num_col].median()
median_values
# Out:
# age       55.00
# bp        80.00
# sg         1.02
# al         0.00
# su         0.00
# bgr      121.00
# bu        42.00
# sc         1.30
# sod      138.00
# pot        4.40
# hemo      12.65
# pcv       40.00
# wc      8000.00
# rc         4.80
# dtype: float64

# %%
df[num_col]=df[num_col].fillna(median_values)

# %%
df[num_col].isnull().sum()
# Out:
# age     0
# bp      0
# sg      0
# al      0
# su      0
# bgr     0
# bu      0
# sc      0
# sod     0
# pot     0
# hemo    0
# pcv     0
# wc      0
# rc      0
# dtype: int64

# %%
mode_values=df.mode().iloc[0]

# %%
df[cat_col]=df[cat_col].fillna(mode_values)

# %%
df[cat_col].isna().sum()
# Out:
# rbc               0
# pc                0
# pcc               0
# ba                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
#few columns are object columns >> convert object to numerical
from sklearn.preprocessing import LabelEncoder
Label_encoder=LabelEncoder()
for col in cat_col:
    df[col]=Label_encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#     age    bp     sg   al   su  rbc  pc  pcc  ba    bgr  ...   pcv      wc  \
# 0  48.0  80.0  1.020  1.0  0.0    1   1    0   0  121.0  ...  44.0  7800.0
# 1   7.0  50.0  1.020  4.0  0.0    1   1    0   0  121.0  ...  38.0  6000.0
# 2  62.0  80.0  1.010  2.0  3.0    1   1    0   0  423.0  ...  31.0  7500.0
# 3  48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  32.0  6700.0
# 4  51.0  80.0  1.010  2.0  0.0    1   1    0   0  106.0  ...  35.0  7300.0
#
#     rc  htn  dm  cad  appet  pe  ane  classification
# 0  5.2    1   2    0      0   0    0               1
# 1  4.8    0   1    0      0   0    0               1
# 2  4.8    0   2    0      1   0    1               1
# 3  3.9    1   1    0      1   1    1               1
# 4  4.6    0   1    0      0   0    0               1
#
# [5 rows x 25 columns]

# %%
df.dtypes
# Out:
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                 int64
# pc                  int64
# pcc                 int64
# ba                  int64
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv               float64
# wc                float64
# rc                float64
# htn                 int64
# dm                  int64
# cad                 int64
# appet               int64
# pe                  int64
# ane                 int64
# classification      int64
# dtype: object
